# %%
import numpy as np

# %%
# Model Prameters
input_size = 2 # no of features
layers = [4, 3] # no of neurons in 1st and 2nd layer
output_size = 2

# %%
def softmax(a):
    e_pa = np.exp(a) # Vector if 'a' is vector
    ans = e_pa / np.sum(e_pa, axis=1, keepdims=True)
    return ans

# %%
class NeuralNetwork:
    
    def __init__(self, input_size, layers, output_size):
        np.random.seed(0)
        
        model = {} # Dictionary
        
        # First Layer
        model['w1'] = np.random.randn(input_size, layers[0]) # randn to generate random weights from a normal distribution
        model['b1'] = np.zeros((1, layers[0]))
        
        # Second Layer
        model['w2'] = np.random.randn(layers[0], layers[1])
        model['b2'] = np.zeros((1, layers[1]))
        
        # Third/Output Layer
        model['w3'] = np.random.randn(layers[1], output_size)
        model['b3'] = np.zeros((1, output_size))
        
        self.model = model
    
    def forward(self, x):
        
        w1, w2, w3 = self.model['w1'], self.model['w2'], self.model['w3']
        b1, b2, b3 = self.model['b1'], self.model['b2'], self.model['b3']
        
        z1 = np.dot(x, w1) + b1
        a1 = np.tanh(z1)
        
        z2 = np.dot(a1, w2) + b2
        a2 = np.tanh(z2)
        
        z3 = np.dot(a2, w3) + b3
        y_ = softmax(z3)
        
        self.activation_outputs = (a1, a2, y_)
        return y_
        
    def backward(self, x, y, learning_rate=0.001):
        
        w1, w2, w3 = self.model['w1'], self.model['w2'], self.model['w3']
        b1, b2, b3 = self.model['b1'], self.model['b2'], self.model['b3']
        m = x.shape[0]
        a1, a2, y_ = self.activation_outputs
        
        delta3 = y_ - y
        dw3 = np.dot(a2.T, delta3)
        db3 = np.sum(delta3, axis=0)/float(m)
        
        delta2 = (1-np.square(a2))*np.dot(delta3, w3.T)
        dw2 = np.dot(a1.T, delta2)
        db2 = np.sum(delta2, axis=0)/float(m)
        
        delta1 = (1-np.square(a1))*np.dot(delta2, w2.T)
        dw1 = np.dot(x.T, delta1)
        db1 = np.sum(delta1, axis=0)/float(m)
        
        # Update the model parameters
        self.model["w1"] -= learning_rate*dw1
        self.model["b1"] -= learning_rate*db1
        
        self.model["w2"] -= learning_rate*dw2
        self.model["b2"] -= learning_rate*db2
        
        self.model["w3"] -= learning_rate*dw3
        self.model["b3"] -= learning_rate*db3
        
    def predict(self, x):
        y_out = self.forward(x)
        return np.argmax(y_out, axis=1)
    
    def summary(self):
        
        w1, w2, w3 = self.model['w1'], self.model['w2'], self.model['w3']
        a1, a2, y_ = self.activation_outputs
        
        print("w1", w1.shape)
        print("a1", a1.shape)
        
        print("w2", w2.shape)
        print("a2", a2.shape)
        
        print("w3", w3.shape)
        print("y_", y_.shape)

# %%
def loss(y_oht, p):
    l = -np.mean(y_oht*np.log(p))
    return l

def one_hot(y, depth):
    
    m = y.shape[0]
    y_oht = np.zeros((m, depth))
    y_oht[np.arange(m), y] = 1
    return y_oht

# %%
# Generating data
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
x, y = make_circles(n_samples=500, shuffle=True, noise=0.2, random_state=1, factor=0.2)

# %%
print(x.shape)
print(y.shape)
# Out:
# (500, 2)
# (500,)

# %%
plt.style.use('seaborn')
plt.scatter(x[:,0], x[:,1], c=y, cmap=plt.cm.Accent)
plt.show()

# %%
# Training our model
model = NeuralNetwork(input_size=2, layers=[10,5],output_size=2)

# %%
print(model.forward(x).shape)
model.summary()
# Out:
# (500, 2)
# w1 (2, 10)
# a1 (500, 10)
# w2 (10, 5)
# a2 (500, 5)
# w3 (5, 2)
# y_ (500, 2)

# %%
def train(x, y, model, epochs, learning_rate, logs=True):
    training_loss = []
    
    classes = 2
    y_oht = one_hot(y, classes)
    
    for ix in range(epochs):
        
        y_ = model.forward(x)
        l = loss(y_oht, y_)
        training_loss.append(l)
        model.backward(x, y_oht, learning_rate)
        
        if(logs):
            print("Epoch %d Loss %.4f"%(ix, l))
    
    return training_loss

# %%
losses = train(x, y, model, 1000, 0.001)
# Out:
# Epoch 0 Loss 0.3571
# Epoch 1 Loss 0.3486
# Epoch 2 Loss 0.3475
# Epoch 3 Loss 0.3466
# Epoch 4 Loss 0.3458
# Epoch 5 Loss 0.3450
# Epoch 6 Loss 0.3442
# Epoch 7 Loss 0.3435
# Epoch 8 Loss 0.3428
# Epoch 9 Loss 0.3421
# Epoch 10 Loss 0.3414
# Epoch 11 Loss 0.3408
# Epoch 12 Loss 0.3401
# Epoch 13 Loss 0.3395
# Epoch 14 Loss 0.3389
# Epoch 15 Loss 0.3383
# Epoch 16 Loss 0.3377
# Epoch 17 Loss 0.3371
# Epoch 18 Loss 0.3365
# Epoch 19 Loss 0.3359
# Epoch 20 Loss 0.3353
# Epoch 21 Loss 0.3347
# Epoch 22 Loss 0.3341
# Epoch 23 Loss 0.3335
# Epoch 24 Loss 0.3329
# Epoch 25 Loss 0.3323
# Epoch 26 Loss 0.3317
# Epoch 27 Loss 0.3310
# Epoch 28 Loss 0.3304
# Epoch 29 Loss 0.3298
# Epoch 30 Loss 0.3292
# Epoch 31 Loss 0.3286
# Epoch 32 Loss 0.3279
# Epoch 33 Loss 0.3273
# Epoch 34 Loss 0.3267
# Epoch 35 Loss 0.3260
# Epoch 36 Loss 0.3254
# Epoch 37 Loss 0.3247
# Epoch 38 Loss 0.3241
# Epoch 39 Loss 0.3234
# Epoch 40 Loss 0.3227
# Epoch 41 Loss 0.3221
# Epoch 42 Loss 0.3214
# Epoch 43 Loss 0.3207
# Epoch 44 Loss 0.3200
# Epoch 45 Loss 0.3193
# Epoch 46 Loss 0.3186
# Epoch 47 Loss 0.3179
# Epoch 48 Loss 0.3172
# Epoch 49 Loss 0.3165
# Epoch 50 Loss 0.3158
# Epoch 51 Loss 0.3151
# Epoch 52 Loss 0.3144
# Epoch 53 Loss 0.3136
# Epoch 54 Loss 0.3129
# Epoch 55 Loss 0.3122
# Epoch 56 Loss 0.3115
# Epoch 57 Loss 0.3107
# Epoch 58 Loss 0.3100
# Epoch 59 Loss 0.3093
# Epoch 60 Loss 0.3085
# Epoch 61 Loss 0.3078
# Epoch 62 Loss 0.3070
# Epoch 63 Loss 0.3063
# Epoch 64 Loss 0.3055
# Epoch 65 Loss 0.3048
# Epoch 66 Loss 0.3041
# Epoch 67 Loss 0.3033
# Epoch 68 Loss 0.3026
# Epoch 69 Loss 0.3018
# Epoch 70 Loss 0.3011
# Epoch 71 Loss 0.3004
# Epoch 72 Loss 0.2996
# Epoch 73 Loss 0.2989
# Epoch 74 Loss 0.2982
# Epoch 75 Loss 0.2974
# Epoch 76 Loss 0.2967
# Epoch 77 Loss 0.2960
# Epoch 78 Loss 0.2952
# Epoch 79 Loss 0.2945
# Epoch 80 Loss 0.2938
# Epoch 81 Loss 0.2931
# Epoch 82 Loss 0.2923
# Epoch 83 Loss 0.2916
# Epoch 84 Loss 0.2909
# Epoch 85 Loss 0.2902
# Epoch 86 Loss 0.2895
# Epoch 87 Loss 0.2888
# Epoch 88 Loss 0.2881
# Epoch 89 Loss 0.2874
# Epoch 90 Loss 0.2867
# Epoch 91 Loss 0.2860
# Epoch 92 Loss 0.2853
# Epoch 93 Loss 0.2846
# Epoch 94 Loss 0.2839
# Epoch 95 Loss 0.2833
# Epoch 96 Loss 0.2826
# Epoch 97 Loss 0.2819
# Epoch 98 Loss 0.2812
# Epoch 99 Loss 0.2806
# Epoch 100 Loss 0.2799
# Epoch 101 Loss 0.2793
# Epoch 102 Loss 0.2786
# Epoch 103 Loss 0.2779
# Epoch 104 Loss 0.2773
# Epoch 105 Loss 0.2767
# Epoch 106 Loss 0.2760
# Epoch 107 Loss 0.2754
# Epoch 108 Loss 0.2748
# Epoch 109 Loss 0.2741
# Epoch 110 Loss 0.2735
# Epoch 111 Loss 0.2729
# Epoch 112 Loss 0.2723
# Epoch 113 Loss 0.2717
# Epoch 114 Loss 0.2711
# Epoch 115 Loss 0.2705
# Epoch 116 Loss 0.2699
# Epoch 117 Loss 0.2693
# Epoch 118 Loss 0.2687
# Epoch 119 Loss 0.2681
# Epoch 120 Loss 0.2676
# Epoch 121 Loss 0.2670
# Epoch 122 Loss 0.2664
# Epoch 123 Loss 0.2659
# Epoch 124 Loss 0.2653
# Epoch 125 Loss 0.2647
# Epoch 126 Loss 0.2642
# Epoch 127 Loss 0.2637
# Epoch 128 Loss 0.2631
# Epoch 129 Loss 0.2626
# Epoch 130 Loss 0.2621
# Epoch 131 Loss 0.2615
# Epoch 132 Loss 0.2610
# Epoch 133 Loss 0.2605
# Epoch 134 Loss 0.2600
# Epoch 135 Loss 0.2595
# Epoch 136 Loss 0.2590
# Epoch 137 Loss 0.2585
# Epoch 138 Loss 0.2580
# Epoch 139 Loss 0.2575
# Epoch 140 Loss 0.2570
# Epoch 141 Loss 0.2565
# Epoch 142 Loss 0.2560
# Epoch 143 Loss 0.2556
# Epoch 144 Loss 0.2551
# Epoch 145 Loss 0.2546
# Epoch 146 Loss 0.2542
# Epoch 147 Loss 0.2537
# Epoch 148 Loss 0.2533
# Epoch 149 Loss 0.2528
# Epoch 150 Loss 0.2524
# Epoch 151 Loss 0.2519
# Epoch 152 Loss 0.2515
# Epoch 153 Loss 0.2511
# Epoch 154 Loss 0.2506
# Epoch 155 Loss 0.2502
# Epoch 156 Loss 0.2498
# Epoch 157 Loss 0.2494
# Epoch 158 Loss 0.2489
# Epoch 159 Loss 0.2485
# Epoch 160 Loss 0.2481
# Epoch 161 Loss 0.2477
# Epoch 162 Loss 0.2473
# Epoch 163 Loss 0.2469
# Epoch 164 Loss 0.2465
# Epoch 165 Loss 0.2461
# Epoch 166 Loss 0.2457
# Epoch 167 Loss 0.2453
# Epoch 168 Loss 0.2450
# Epoch 169 Loss 0.2446
# Epoch 170 Loss 0.2442
# Epoch 171 Loss 0.2438
# Epoch 172 Loss 0.2434
# Epoch 173 Loss 0.2431
# Epoch 174 Loss 0.2427
# Epoch 175 Loss 0.2423
# Epoch 176 Loss 0.2420
# Epoch 177 Loss 0.2416
# Epoch 178 Loss 0.2412
# Epoch 179 Loss 0.2409
# Epoch 180 Loss 0.2405
# Epoch 181 Loss 0.2402
# Epoch 182 Loss 0.2398
# Epoch 183 Loss 0.2395
# Epoch 184 Loss 0.2391
# Epoch 185 Loss 0.2388
# Epoch 186 Loss 0.2385
# Epoch 187 Loss 0.2381
# Epoch 188 Loss 0.2378
# Epoch 189 Loss 0.2374
# Epoch 190 Loss 0.2371
# Epoch 191 Loss 0.2368
# Epoch 192 Loss 0.2364
# Epoch 193 Loss 0.2361
# Epoch 194 Loss 0.2358
# Epoch 195 Loss 0.2355
# Epoch 196 Loss 0.2351
# Epoch 197 Loss 0.2348
# Epoch 198 Loss 0.2345
# Epoch 199 Loss 0.2342
# Epoch 200 Loss 0.2339
# Epoch 201 Loss 0.2336
# Epoch 202 Loss 0.2333
# Epoch 203 Loss 0.2329
# Epoch 204 Loss 0.2326
# Epoch 205 Loss 0.2323
# Epoch 206 Loss 0.2320
# Epoch 207 Loss 0.2317
# Epoch 208 Loss 0.2314
# Epoch 209 Loss 0.2311
# Epoch 210 Loss 0.2308
# Epoch 211 Loss 0.2305
# Epoch 212 Loss 0.2302
# Epoch 213 Loss 0.2299
# Epoch 214 Loss 0.2296
# Epoch 215 Loss 0.2293
# Epoch 216 Loss 0.2290
# Epoch 217 Loss 0.2287
# Epoch 218 Loss 0.2285
# Epoch 219 Loss 0.2282
# Epoch 220 Loss 0.2279
# Epoch 221 Loss 0.2276
# Epoch 222 Loss 0.2273
# Epoch 223 Loss 0.2270
# Epoch 224 Loss 0.2267
# Epoch 225 Loss 0.2264
# Epoch 226 Loss 0.2262
# Epoch 227 Loss 0.2259
# Epoch 228 Loss 0.2256
# Epoch 229 Loss 0.2253
# Epoch 230 Loss 0.2250
# Epoch 231 Loss 0.2248
# Epoch 232 Loss 0.2245
# Epoch 233 Loss 0.2242
# Epoch 234 Loss 0.2239
# Epoch 235 Loss 0.2236
# Epoch 236 Loss 0.2234
# Epoch 237 Loss 0.2231
# Epoch 238 Loss 0.2228
# Epoch 239 Loss 0.2225
# Epoch 240 Loss 0.2223
# Epoch 241 Loss 0.2220
# Epoch 242 Loss 0.2217
# Epoch 243 Loss 0.2215
# Epoch 244 Loss 0.2212
# Epoch 245 Loss 0.2209
# Epoch 246 Loss 0.2206
# Epoch 247 Loss 0.2204
# Epoch 248 Loss 0.2201
# Epoch 249 Loss 0.2198
# Epoch 250 Loss 0.2196
# Epoch 251 Loss 0.2193
# Epoch 252 Loss 0.2190
# Epoch 253 Loss 0.2187
# Epoch 254 Loss 0.2185
# Epoch 255 Loss 0.2182
# Epoch 256 Loss 0.2179
# Epoch 257 Loss 0.2177
# Epoch 258 Loss 0.2174
# Epoch 259 Loss 0.2171
# Epoch 260 Loss 0.2168
# Epoch 261 Loss 0.2166
# Epoch 262 Loss 0.2163
# Epoch 263 Loss 0.2160
# Epoch 264 Loss 0.2158
# Epoch 265 Loss 0.2155
# Epoch 266 Loss 0.2152
# Epoch 267 Loss 0.2149
# Epoch 268 Loss 0.2147
# Epoch 269 Loss 0.2144
# Epoch 270 Loss 0.2141
# Epoch 271 Loss 0.2138
# Epoch 272 Loss 0.2136
# Epoch 273 Loss 0.2133
# Epoch 274 Loss 0.2130
# Epoch 275 Loss 0.2127
# Epoch 276 Loss 0.2125
# Epoch 277 Loss 0.2122
# Epoch 278 Loss 0.2119
# Epoch 279 Loss 0.2116
# Epoch 280 Loss 0.2113
# Epoch 281 Loss 0.2110
# Epoch 282 Loss 0.2107
# Epoch 283 Loss 0.2105
# Epoch 284 Loss 0.2102
# Epoch 285 Loss 0.2099
# Epoch 286 Loss 0.2096
# Epoch 287 Loss 0.2093
# Epoch 288 Loss 0.2090
# Epoch 289 Loss 0.2087
# Epoch 290 Loss 0.2084
# Epoch 291 Loss 0.2081
# Epoch 292 Loss 0.2078
# Epoch 293 Loss 0.2075
# Epoch 294 Loss 0.2072
# Epoch 295 Loss 0.2069
# Epoch 296 Loss 0.2066
# Epoch 297 Loss 0.2063
# Epoch 298 Loss 0.2059
# Epoch 299 Loss 0.2056
# Epoch 300 Loss 0.2053
# Epoch 301 Loss 0.2050
# Epoch 302 Loss 0.2047
# Epoch 303 Loss 0.2043
# Epoch 304 Loss 0.2040
# Epoch 305 Loss 0.2037
# Epoch 306 Loss 0.2033
# Epoch 307 Loss 0.2030
# Epoch 308 Loss 0.2026
# Epoch 309 Loss 0.2023
# Epoch 310 Loss 0.2019
# Epoch 311 Loss 0.2016
# Epoch 312 Loss 0.2012
# Epoch 313 Loss 0.2008
# Epoch 314 Loss 0.2005
# Epoch 315 Loss 0.2001
# Epoch 316 Loss 0.1997
# Epoch 317 Loss 0.1994
# Epoch 318 Loss 0.1990
# Epoch 319 Loss 0.1986
# Epoch 320 Loss 0.1982
# Epoch 321 Loss 0.1979
# Epoch 322 Loss 0.1980
# Epoch 323 Loss 0.1998
# Epoch 324 Loss 0.2079
# Epoch 325 Loss 0.2357
# Epoch 326 Loss 0.2785
# Epoch 327 Loss 0.2976
# Epoch 328 Loss 0.2664
# Epoch 329 Loss 0.2579
# Epoch 330 Loss 0.2373
# Epoch 331 Loss 0.2338
# Epoch 332 Loss 0.2262
# Epoch 333 Loss 0.2253
# Epoch 334 Loss 0.2213
# Epoch 335 Loss 0.2217
# Epoch 336 Loss 0.2190
# Epoch 337 Loss 0.2200
# Epoch 338 Loss 0.2177
# Epoch 339 Loss 0.2190
# Epoch 340 Loss 0.2167
# Epoch 341 Loss 0.2181
# Epoch 342 Loss 0.2157
# Epoch 343 Loss 0.2171
# Epoch 344 Loss 0.2147
# Epoch 345 Loss 0.2161
# Epoch 346 Loss 0.2137
# Epoch 347 Loss 0.2150
# Epoch 348 Loss 0.2127
# Epoch 349 Loss 0.2141
# Epoch 350 Loss 0.2118
# Epoch 351 Loss 0.2132
# Epoch 352 Loss 0.2110
# Epoch 353 Loss 0.2124
# Epoch 354 Loss 0.2102
# Epoch 355 Loss 0.2117
# Epoch 356 Loss 0.2094
# Epoch 357 Loss 0.2110
# Epoch 358 Loss 0.2087
# Epoch 359 Loss 0.2103
# Epoch 360 Loss 0.2080
# Epoch 361 Loss 0.2097
# Epoch 362 Loss 0.2074
# Epoch 363 Loss 0.2091
# Epoch 364 Loss 0.2067
# Epoch 365 Loss 0.2085
# Epoch 366 Loss 0.2061
# Epoch 367 Loss 0.2080
# Epoch 368 Loss 0.2055
# Epoch 369 Loss 0.2075
# Epoch 370 Loss 0.2049
# Epoch 371 Loss 0.2070
# Epoch 372 Loss 0.2043
# Epoch 373 Loss 0.2065
# Epoch 374 Loss 0.2038
# Epoch 375 Loss 0.2060
# Epoch 376 Loss 0.2032
# Epoch 377 Loss 0.2056
# Epoch 378 Loss 0.2027
# Epoch 379 Loss 0.2052
# Epoch 380 Loss 0.2021
# Epoch 381 Loss 0.2047
# Epoch 382 Loss 0.2016
# Epoch 383 Loss 0.2043
# Epoch 384 Loss 0.2011
# Epoch 385 Loss 0.2039
# Epoch 386 Loss 0.2006
# Epoch 387 Loss 0.2036
# Epoch 388 Loss 0.2000
# Epoch 389 Loss 0.2032
# Epoch 390 Loss 0.1995
# Epoch 391 Loss 0.2028
# Epoch 392 Loss 0.1990
# Epoch 393 Loss 0.2024
# Epoch 394 Loss 0.1984
# Epoch 395 Loss 0.2021
# Epoch 396 Loss 0.1979
# Epoch 397 Loss 0.2017
# Epoch 398 Loss 0.1974
# Epoch 399 Loss 0.2014
# Epoch 400 Loss 0.1968
# Epoch 401 Loss 0.2011
# Epoch 402 Loss 0.1963
# Epoch 403 Loss 0.2007
# Epoch 404 Loss 0.1957
# Epoch 405 Loss 0.2004
# Epoch 406 Loss 0.1952
# Epoch 407 Loss 0.2000
# Epoch 408 Loss 0.1946
# Epoch 409 Loss 0.1997
# Epoch 410 Loss 0.1940
# Epoch 411 Loss 0.1994
# Epoch 412 Loss 0.1935
# Epoch 413 Loss 0.1990
# Epoch 414 Loss 0.1929
# Epoch 415 Loss 0.1987
# Epoch 416 Loss 0.1923
# Epoch 417 Loss 0.1983
# Epoch 418 Loss 0.1917
# Epoch 419 Loss 0.1979
# Epoch 420 Loss 0.1911
# Epoch 421 Loss 0.1976
# Epoch 422 Loss 0.1905
# Epoch 423 Loss 0.1972
# Epoch 424 Loss 0.1899
# Epoch 425 Loss 0.1968
# Epoch 426 Loss 0.1893
# Epoch 427 Loss 0.1963
# Epoch 428 Loss 0.1887
# Epoch 429 Loss 0.1959
# Epoch 430 Loss 0.1881
# Epoch 431 Loss 0.1954
# Epoch 432 Loss 0.1875
# Epoch 433 Loss 0.1950
# Epoch 434 Loss 0.1869
# Epoch 435 Loss 0.1945
# Epoch 436 Loss 0.1862
# Epoch 437 Loss 0.1939
# Epoch 438 Loss 0.1856
# Epoch 439 Loss 0.1934
# Epoch 440 Loss 0.1849
# Epoch 441 Loss 0.1928
# Epoch 442 Loss 0.1842
# Epoch 443 Loss 0.1922
# Epoch 444 Loss 0.1835
# Epoch 445 Loss 0.1915
# Epoch 446 Loss 0.1828
# Epoch 447 Loss 0.1909
# Epoch 448 Loss 0.1821
# Epoch 449 Loss 0.1902
# Epoch 450 Loss 0.1814
# Epoch 451 Loss 0.1895
# Epoch 452 Loss 0.1806
# Epoch 453 Loss 0.1888
# Epoch 454 Loss 0.1798
# Epoch 455 Loss 0.1881
# Epoch 456 Loss 0.1790
# Epoch 457 Loss 0.1874
# Epoch 458 Loss 0.1782
# Epoch 459 Loss 0.1867
# Epoch 460 Loss 0.1774
# Epoch 461 Loss 0.1860
# Epoch 462 Loss 0.1765
# Epoch 463 Loss 0.1853
# Epoch 464 Loss 0.1757
# Epoch 465 Loss 0.1846
# Epoch 466 Loss 0.1748
# Epoch 467 Loss 0.1838
# Epoch 468 Loss 0.1739
# Epoch 469 Loss 0.1831
# Epoch 470 Loss 0.1730
# Epoch 471 Loss 0.1824
# Epoch 472 Loss 0.1721
# Epoch 473 Loss 0.1817
# Epoch 474 Loss 0.1712
# Epoch 475 Loss 0.1810
# Epoch 476 Loss 0.1703
# Epoch 477 Loss 0.1803
# Epoch 478 Loss 0.1694
# Epoch 479 Loss 0.1796
# Epoch 480 Loss 0.1685
# Epoch 481 Loss 0.1788
# Epoch 482 Loss 0.1676
# Epoch 483 Loss 0.1781
# Epoch 484 Loss 0.1666
# Epoch 485 Loss 0.1774
# Epoch 486 Loss 0.1657
# Epoch 487 Loss 0.1767
# Epoch 488 Loss 0.1648
# Epoch 489 Loss 0.1759
# Epoch 490 Loss 0.1639
# Epoch 491 Loss 0.1752
# Epoch 492 Loss 0.1630
# Epoch 493 Loss 0.1745
# Epoch 494 Loss 0.1621
# Epoch 495 Loss 0.1737
# Epoch 496 Loss 0.1612
# Epoch 497 Loss 0.1730
# Epoch 498 Loss 0.1603
# Epoch 499 Loss 0.1722
# Epoch 500 Loss 0.1594
# Epoch 501 Loss 0.1714
# Epoch 502 Loss 0.1585
# Epoch 503 Loss 0.1706
# Epoch 504 Loss 0.1576
# Epoch 505 Loss 0.1698
# Epoch 506 Loss 0.1567
# Epoch 507 Loss 0.1689
# Epoch 508 Loss 0.1558
# Epoch 509 Loss 0.1681
# Epoch 510 Loss 0.1550
# Epoch 511 Loss 0.1672
# Epoch 512 Loss 0.1541
# Epoch 513 Loss 0.1663
# Epoch 514 Loss 0.1532
# Epoch 515 Loss 0.1654
# Epoch 516 Loss 0.1524
# Epoch 517 Loss 0.1644
# Epoch 518 Loss 0.1515
# Epoch 519 Loss 0.1634
# Epoch 520 Loss 0.1506
# Epoch 521 Loss 0.1624
# Epoch 522 Loss 0.1498
# Epoch 523 Loss 0.1614
# Epoch 524 Loss 0.1489
# Epoch 525 Loss 0.1603
# Epoch 526 Loss 0.1480
# Epoch 527 Loss 0.1592
# Epoch 528 Loss 0.1472
# Epoch 529 Loss 0.1581
# Epoch 530 Loss 0.1463
# Epoch 531 Loss 0.1569
# Epoch 532 Loss 0.1454
# Epoch 533 Loss 0.1557
# Epoch 534 Loss 0.1445
# Epoch 535 Loss 0.1544
# Epoch 536 Loss 0.1435
# Epoch 537 Loss 0.1531
# Epoch 538 Loss 0.1426
# Epoch 539 Loss 0.1517
# Epoch 540 Loss 0.1416
# Epoch 541 Loss 0.1502
# Epoch 542 Loss 0.1406
# Epoch 543 Loss 0.1487
# Epoch 544 Loss 0.1395
# Epoch 545 Loss 0.1471
# Epoch 546 Loss 0.1384
# Epoch 547 Loss 0.1455
# Epoch 548 Loss 0.1372
# Epoch 549 Loss 0.1437
# Epoch 550 Loss 0.1359
# Epoch 551 Loss 0.1418
# Epoch 552 Loss 0.1346
# Epoch 553 Loss 0.1398
# Epoch 554 Loss 0.1332
# Epoch 555 Loss 0.1377
# Epoch 556 Loss 0.1316
# Epoch 557 Loss 0.1354
# Epoch 558 Loss 0.1298
# Epoch 559 Loss 0.1328
# Epoch 560 Loss 0.1279
# Epoch 561 Loss 0.1300
# Epoch 562 Loss 0.1256
# Epoch 563 Loss 0.1268
# Epoch 564 Loss 0.1229
# Epoch 565 Loss 0.1230
# Epoch 566 Loss 0.1196
# Epoch 567 Loss 0.1183
# Epoch 568 Loss 0.1150
# Epoch 569 Loss 0.1120
# Epoch 570 Loss 0.1085
# Epoch 571 Loss 0.1033
# Epoch 572 Loss 0.0990
# Epoch 573 Loss 0.0928
# Epoch 574 Loss 0.0888
# Epoch 575 Loss 0.0854
# Epoch 576 Loss 0.0837
# Epoch 577 Loss 0.0826
# Epoch 578 Loss 0.0818
# Epoch 579 Loss 0.0812
# Epoch 580 Loss 0.0807
# Epoch 581 Loss 0.0801
# Epoch 582 Loss 0.0797
# Epoch 583 Loss 0.0792
# Epoch 584 Loss 0.0788
# Epoch 585 Loss 0.0784
# Epoch 586 Loss 0.0779
# Epoch 587 Loss 0.0775
# Epoch 588 Loss 0.0772
# Epoch 589 Loss 0.0768
# Epoch 590 Loss 0.0764
# Epoch 591 Loss 0.0761
# Epoch 592 Loss 0.0757
# Epoch 593 Loss 0.0754
# Epoch 594 Loss 0.0751
# Epoch 595 Loss 0.0747
# Epoch 596 Loss 0.0744
# Epoch 597 Loss 0.0741
# Epoch 598 Loss 0.0738
# Epoch 599 Loss 0.0735
# Epoch 600 Loss 0.0732
# Epoch 601 Loss 0.0729
# Epoch 602 Loss 0.0726
# Epoch 603 Loss 0.0724
# Epoch 604 Loss 0.0721
# Epoch 605 Loss 0.0718
# Epoch 606 Loss 0.0716
# Epoch 607 Loss 0.0713
# Epoch 608 Loss 0.0711
# Epoch 609 Loss 0.0708
# Epoch 610 Loss 0.0706
# Epoch 611 Loss 0.0703
# Epoch 612 Loss 0.0701
# Epoch 613 Loss 0.0699
# Epoch 614 Loss 0.0696
# Epoch 615 Loss 0.0694
# Epoch 616 Loss 0.0692
# Epoch 617 Loss 0.0690
# Epoch 618 Loss 0.0688
# Epoch 619 Loss 0.0685
# Epoch 620 Loss 0.0683
# Epoch 621 Loss 0.0681
# Epoch 622 Loss 0.0679
# Epoch 623 Loss 0.0677
# Epoch 624 Loss 0.0675
# Epoch 625 Loss 0.0673
# Epoch 626 Loss 0.0671
# Epoch 627 Loss 0.0669
# Epoch 628 Loss 0.0668
# Epoch 629 Loss 0.0666
# Epoch 630 Loss 0.0664
# Epoch 631 Loss 0.0662
# Epoch 632 Loss 0.0660
# Epoch 633 Loss 0.0659
# Epoch 634 Loss 0.0657
# Epoch 635 Loss 0.0655
# Epoch 636 Loss 0.0653
# Epoch 637 Loss 0.0652
# Epoch 638 Loss 0.0650
# Epoch 639 Loss 0.0649
# Epoch 640 Loss 0.0647
# Epoch 641 Loss 0.0645
# Epoch 642 Loss 0.0644
# Epoch 643 Loss 0.0642
# Epoch 644 Loss 0.0641
# Epoch 645 Loss 0.0639
# Epoch 646 Loss 0.0638
# Epoch 647 Loss 0.0636
# Epoch 648 Loss 0.0635
# Epoch 649 Loss 0.0633
# Epoch 650 Loss 0.0632
# Epoch 651 Loss 0.0631
# Epoch 652 Loss 0.0629
# Epoch 653 Loss 0.0628
# Epoch 654 Loss 0.0627
# Epoch 655 Loss 0.0625
# Epoch 656 Loss 0.0624
# Epoch 657 Loss 0.0623
# Epoch 658 Loss 0.0621
# Epoch 659 Loss 0.0620
# Epoch 660 Loss 0.0619
# Epoch 661 Loss 0.0618
# Epoch 662 Loss 0.0616
# Epoch 663 Loss 0.0615
# Epoch 664 Loss 0.0614
# Epoch 665 Loss 0.0613
# Epoch 666 Loss 0.0612
# Epoch 667 Loss 0.0610
# Epoch 668 Loss 0.0609
# Epoch 669 Loss 0.0608
# Epoch 670 Loss 0.0607
# Epoch 671 Loss 0.0606
# Epoch 672 Loss 0.0605
# Epoch 673 Loss 0.0604
# Epoch 674 Loss 0.0603
# Epoch 675 Loss 0.0602
# Epoch 676 Loss 0.0601
# Epoch 677 Loss 0.0600
# Epoch 678 Loss 0.0599
# Epoch 679 Loss 0.0597
# Epoch 680 Loss 0.0596
# Epoch 681 Loss 0.0595
# Epoch 682 Loss 0.0595
# Epoch 683 Loss 0.0594
# Epoch 684 Loss 0.0593
# Epoch 685 Loss 0.0592
# Epoch 686 Loss 0.0591
# Epoch 687 Loss 0.0590
# Epoch 688 Loss 0.0589
# Epoch 689 Loss 0.0588
# Epoch 690 Loss 0.0587
# Epoch 691 Loss 0.0586
# Epoch 692 Loss 0.0585
# Epoch 693 Loss 0.0584
# Epoch 694 Loss 0.0583
# Epoch 695 Loss 0.0583
# Epoch 696 Loss 0.0582
# Epoch 697 Loss 0.0581
# Epoch 698 Loss 0.0580
# Epoch 699 Loss 0.0579
# Epoch 700 Loss 0.0578
# Epoch 701 Loss 0.0577
# Epoch 702 Loss 0.0577
# Epoch 703 Loss 0.0576
# Epoch 704 Loss 0.0575
# Epoch 705 Loss 0.0574
# Epoch 706 Loss 0.0573
# Epoch 707 Loss 0.0573
# Epoch 708 Loss 0.0572
# Epoch 709 Loss 0.0571
# Epoch 710 Loss 0.0570
# Epoch 711 Loss 0.0570
# Epoch 712 Loss 0.0569
# Epoch 713 Loss 0.0568
# Epoch 714 Loss 0.0567
# Epoch 715 Loss 0.0567
# Epoch 716 Loss 0.0566
# Epoch 717 Loss 0.0565
# Epoch 718 Loss 0.0564
# Epoch 719 Loss 0.0564
# Epoch 720 Loss 0.0563
# Epoch 721 Loss 0.0562
# Epoch 722 Loss 0.0562
# Epoch 723 Loss 0.0561
# Epoch 724 Loss 0.0560
# Epoch 725 Loss 0.0560
# Epoch 726 Loss 0.0559
# Epoch 727 Loss 0.0558
# Epoch 728 Loss 0.0558
# Epoch 729 Loss 0.0557
# Epoch 730 Loss 0.0556
# Epoch 731 Loss 0.0556
# Epoch 732 Loss 0.0555
# Epoch 733 Loss 0.0554
# Epoch 734 Loss 0.0554
# Epoch 735 Loss 0.0553
# Epoch 736 Loss 0.0552
# Epoch 737 Loss 0.0552
# Epoch 738 Loss 0.0551
# Epoch 739 Loss 0.0551
# Epoch 740 Loss 0.0550
# Epoch 741 Loss 0.0549
# Epoch 742 Loss 0.0549
# Epoch 743 Loss 0.0548
# Epoch 744 Loss 0.0548
# Epoch 745 Loss 0.0547
# Epoch 746 Loss 0.0546
# Epoch 747 Loss 0.0546
# Epoch 748 Loss 0.0545
# Epoch 749 Loss 0.0545
# Epoch 750 Loss 0.0544
# Epoch 751 Loss 0.0544
# Epoch 752 Loss 0.0543
# Epoch 753 Loss 0.0543
# Epoch 754 Loss 0.0542
# Epoch 755 Loss 0.0541
# Epoch 756 Loss 0.0541
# Epoch 757 Loss 0.0540
# Epoch 758 Loss 0.0540
# Epoch 759 Loss 0.0539
# Epoch 760 Loss 0.0539
# Epoch 761 Loss 0.0538
# Epoch 762 Loss 0.0538
# Epoch 763 Loss 0.0537
# Epoch 764 Loss 0.0537
# Epoch 765 Loss 0.0536
# Epoch 766 Loss 0.0536
# Epoch 767 Loss 0.0535
# Epoch 768 Loss 0.0535
# Epoch 769 Loss 0.0534
# Epoch 770 Loss 0.0534
# Epoch 771 Loss 0.0533
# Epoch 772 Loss 0.0533
# Epoch 773 Loss 0.0532
# Epoch 774 Loss 0.0532
# Epoch 775 Loss 0.0531
# Epoch 776 Loss 0.0531
# Epoch 777 Loss 0.0530
# Epoch 778 Loss 0.0530
# Epoch 779 Loss 0.0529
# Epoch 780 Loss 0.0529
# Epoch 781 Loss 0.0528
# Epoch 782 Loss 0.0528
# Epoch 783 Loss 0.0527
# Epoch 784 Loss 0.0527
# Epoch 785 Loss 0.0526
# Epoch 786 Loss 0.0526
# Epoch 787 Loss 0.0525
# Epoch 788 Loss 0.0525
# Epoch 789 Loss 0.0524
# Epoch 790 Loss 0.0524
# Epoch 791 Loss 0.0524
# Epoch 792 Loss 0.0523
# Epoch 793 Loss 0.0523
# Epoch 794 Loss 0.0522
# Epoch 795 Loss 0.0522
# Epoch 796 Loss 0.0521
# Epoch 797 Loss 0.0521
# Epoch 798 Loss 0.0520
# Epoch 799 Loss 0.0520
# Epoch 800 Loss 0.0520
# Epoch 801 Loss 0.0519
# Epoch 802 Loss 0.0519
# Epoch 803 Loss 0.0518
# Epoch 804 Loss 0.0518
# Epoch 805 Loss 0.0517
# Epoch 806 Loss 0.0517
# Epoch 807 Loss 0.0517
# Epoch 808 Loss 0.0516
# Epoch 809 Loss 0.0516
# Epoch 810 Loss 0.0515
# Epoch 811 Loss 0.0515
# Epoch 812 Loss 0.0515
# Epoch 813 Loss 0.0514
# Epoch 814 Loss 0.0514
# Epoch 815 Loss 0.0513
# Epoch 816 Loss 0.0513
# Epoch 817 Loss 0.0513
# Epoch 818 Loss 0.0512
# Epoch 819 Loss 0.0512
# Epoch 820 Loss 0.0511
# Epoch 821 Loss 0.0511
# Epoch 822 Loss 0.0511
# Epoch 823 Loss 0.0510
# Epoch 824 Loss 0.0510
# Epoch 825 Loss 0.0509
# Epoch 826 Loss 0.0509
# Epoch 827 Loss 0.0509
# Epoch 828 Loss 0.0508
# Epoch 829 Loss 0.0508
# Epoch 830 Loss 0.0508
# Epoch 831 Loss 0.0507
# Epoch 832 Loss 0.0507
# Epoch 833 Loss 0.0506
# Epoch 834 Loss 0.0506
# Epoch 835 Loss 0.0506
# Epoch 836 Loss 0.0505
# Epoch 837 Loss 0.0505
# Epoch 838 Loss 0.0505
# Epoch 839 Loss 0.0505
# Epoch 840 Loss 0.0505
# Epoch 841 Loss 0.0505
# Epoch 842 Loss 0.0505
# Epoch 843 Loss 0.0505
# Epoch 844 Loss 0.0506
# Epoch 845 Loss 0.0507
# Epoch 846 Loss 0.0509
# Epoch 847 Loss 0.0512
# Epoch 848 Loss 0.0518
# Epoch 849 Loss 0.0526
# Epoch 850 Loss 0.0540
# Epoch 851 Loss 0.0563
# Epoch 852 Loss 0.0606
# Epoch 853 Loss 0.0693
# Epoch 854 Loss 0.0975
# Epoch 855 Loss 0.2721
# Epoch 856 Loss 0.9371
# Epoch 857 Loss 0.3541
# Epoch 858 Loss 0.1615
# Epoch 859 Loss 0.1148
# Epoch 860 Loss 0.0894
# Epoch 861 Loss 0.0731
# Epoch 862 Loss 0.0634
# Epoch 863 Loss 0.0582
# Epoch 864 Loss 0.0557
# Epoch 865 Loss 0.0545
# Epoch 866 Loss 0.0539
# Epoch 867 Loss 0.0535
# Epoch 868 Loss 0.0532
# Epoch 869 Loss 0.0530
# Epoch 870 Loss 0.0527
# Epoch 871 Loss 0.0525
# Epoch 872 Loss 0.0523
# Epoch 873 Loss 0.0522
# Epoch 874 Loss 0.0520
# Epoch 875 Loss 0.0519
# Epoch 876 Loss 0.0517
# Epoch 877 Loss 0.0516
# Epoch 878 Loss 0.0515
# Epoch 879 Loss 0.0514
# Epoch 880 Loss 0.0513
# Epoch 881 Loss 0.0512
# Epoch 882 Loss 0.0511
# Epoch 883 Loss 0.0510
# Epoch 884 Loss 0.0509
# Epoch 885 Loss 0.0508
# Epoch 886 Loss 0.0507
# Epoch 887 Loss 0.0506
# Epoch 888 Loss 0.0506
# Epoch 889 Loss 0.0505
# Epoch 890 Loss 0.0504
# Epoch 891 Loss 0.0504
# Epoch 892 Loss 0.0503
# Epoch 893 Loss 0.0502
# Epoch 894 Loss 0.0502
# Epoch 895 Loss 0.0501
# Epoch 896 Loss 0.0501
# Epoch 897 Loss 0.0500
# Epoch 898 Loss 0.0500
# Epoch 899 Loss 0.0499
# Epoch 900 Loss 0.0499
# Epoch 901 Loss 0.0498
# Epoch 902 Loss 0.0498
# Epoch 903 Loss 0.0497
# Epoch 904 Loss 0.0497
# Epoch 905 Loss 0.0496
# Epoch 906 Loss 0.0496
# Epoch 907 Loss 0.0495
# Epoch 908 Loss 0.0495
# Epoch 909 Loss 0.0494
# Epoch 910 Loss 0.0494
# Epoch 911 Loss 0.0494
# Epoch 912 Loss 0.0493
# Epoch 913 Loss 0.0493
# Epoch 914 Loss 0.0492
# Epoch 915 Loss 0.0492
# Epoch 916 Loss 0.0492
# Epoch 917 Loss 0.0491
# Epoch 918 Loss 0.0491
# Epoch 919 Loss 0.0490
# Epoch 920 Loss 0.0490
# Epoch 921 Loss 0.0490
# Epoch 922 Loss 0.0489
# Epoch 923 Loss 0.0489
# Epoch 924 Loss 0.0489
# Epoch 925 Loss 0.0488
# Epoch 926 Loss 0.0488
# Epoch 927 Loss 0.0487
# Epoch 928 Loss 0.0487
# Epoch 929 Loss 0.0487
# Epoch 930 Loss 0.0486
# Epoch 931 Loss 0.0486
# Epoch 932 Loss 0.0486
# Epoch 933 Loss 0.0485
# Epoch 934 Loss 0.0485
# Epoch 935 Loss 0.0485
# Epoch 936 Loss 0.0484
# Epoch 937 Loss 0.0484
# Epoch 938 Loss 0.0484
# Epoch 939 Loss 0.0483
# Epoch 940 Loss 0.0483
# Epoch 941 Loss 0.0483
# Epoch 942 Loss 0.0482
# Epoch 943 Loss 0.0482
# Epoch 944 Loss 0.0482
# Epoch 945 Loss 0.0481
# Epoch 946 Loss 0.0481
# Epoch 947 Loss 0.0481
# Epoch 948 Loss 0.0480
# Epoch 949 Loss 0.0480
# Epoch 950 Loss 0.0480
# Epoch 951 Loss 0.0479
# Epoch 952 Loss 0.0479
# Epoch 953 Loss 0.0479
# Epoch 954 Loss 0.0478
# Epoch 955 Loss 0.0478
# Epoch 956 Loss 0.0478
# Epoch 957 Loss 0.0478
# Epoch 958 Loss 0.0477
# Epoch 959 Loss 0.0477
# Epoch 960 Loss 0.0477
# Epoch 961 Loss 0.0476
# Epoch 962 Loss 0.0476
# Epoch 963 Loss 0.0476
# Epoch 964 Loss 0.0475
# Epoch 965 Loss 0.0475
# Epoch 966 Loss 0.0475
# Epoch 967 Loss 0.0475
# Epoch 968 Loss 0.0474
# Epoch 969 Loss 0.0474
# Epoch 970 Loss 0.0474
# Epoch 971 Loss 0.0473
# Epoch 972 Loss 0.0473
# Epoch 973 Loss 0.0473
# Epoch 974 Loss 0.0473
# Epoch 975 Loss 0.0472
# Epoch 976 Loss 0.0472
# Epoch 977 Loss 0.0472
# Epoch 978 Loss 0.0471
# Epoch 979 Loss 0.0471
# Epoch 980 Loss 0.0471
# Epoch 981 Loss 0.0471
# Epoch 982 Loss 0.0470
# Epoch 983 Loss 0.0470
# Epoch 984 Loss 0.0470
# Epoch 985 Loss 0.0470
# Epoch 986 Loss 0.0469
# Epoch 987 Loss 0.0469
# Epoch 988 Loss 0.0469
# Epoch 989 Loss 0.0468
# Epoch 990 Loss 0.0468
# Epoch 991 Loss 0.0468
# Epoch 992 Loss 0.0468
# Epoch 993 Loss 0.0467
# Epoch 994 Loss 0.0467
# Epoch 995 Loss 0.0467
# Epoch 996 Loss 0.0467
# Epoch 997 Loss 0.0466
# Epoch 998 Loss 0.0466
# Epoch 999 Loss 0.0466

# %%
plt.plot(losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
def plot_decision_boundary(model, X, y,cmap=plt.cm.jet):
    """
    Given a model(a function) and a set of points(X), corresponding labels(y), scatter the points in X with color coding
    according to y. Also use the model to predict the label at grid points to get the region for each label, and thus the 
    descion boundary.
    Example usage:
    say we have a function predict(x,other params) which makes 0/1 prediction for point x and we want to plot
    train set then call as:
    plot_decision_boundary(lambda x:predict(x,other params),X_train,Y_train)
    params(3): 
        model : a function which expectes the point to make 0/1 label prediction
        X : a (mx2) numpy array with the points
        y : a (mx1) numpy array with labels
    outputs(None)
    """
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole grid
    Z = model(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.ylabel('x2')
    plt.xlabel('x1')
    plt.style.use("seaborn")
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.jet)

# %%
import itertools

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Find accuracy
plot_decision_boundary(lambda x:model.predict(x), x, y)

# %%
plt.scatter(x[:,0], x[:,1], c=y, cmap=plt.cm.Accent)
plt.show()

# %%
outputs = model.predict(x)

# %%
training_accuracy = np.sum(outputs==y)/y.shape[0]
print("Training accuracy %.4f"%training_accuracy)
# Out:
# Training accuracy 0.9680

# %% [markdown]
# ## Other datasets

# %%
Some changes
