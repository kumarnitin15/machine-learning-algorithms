# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn import datasets

# %%
# some helper functions

def getkey(item):
    return item[0]

def distance(x1, x2):
    return ((x1-x2) ** 2).sum()

def accuracy(x_test, y_test, x_train, y_train, k):
    y_pred = []
    for i in range(len(x_test)):
        y_pred.append(KNN(x_test[i], x_train, y_train, k))
    return (np.array(y_pred) == y_test).sum() / len(y_test)

def r2_score(x_test, y_test, x_train, y_train, k):
    y_pred = []
    for i in range(len(x_test)):
        y_pred.append(KNN(x_test[i], x_train, y_train, k))
    tot = ((y_test - y_test.mean()) ** 2).sum()
    res = ((y_test - y_pred) ** 2).sum()
    score = 1 - (res / tot)
    return score

# %% [markdown]
# ### Data collection

# %%
# Classification data
x, y = make_classification(n_samples=300, n_features=2, n_redundant=0)

# Regression data
boston = datasets.load_boston()
df = pd.DataFrame(boston.data, boston.target)
x_train = np.array([df[column] for column in df.columns]).T
y_train = boston.target

# %% [markdown]
# ### For a classification problem

# %%
def KNN(x, x_train, y_train, k):
    d = []
    for i in range(len(x_train)):
        d.append([distance(x, x_train[i]), y_train[i]])
    d = sorted(d, key = getkey)
    num_of_classes = len(np.unique(y_train))
    nearest_neighbours = [d[i][1] for i in range(k)]
    output = 0
    max_count = nearest_neighbours.count(0)
    for i in range(1, num_of_classes):
        c = nearest_neighbours.count(i)
        if c > max_count:
            max_count = c
            output = i
    return output

# %%
# Decision boundary generated
y_pred = []
for i in range(len(x)):
    y_pred.append(KNN(x[i], x, y, 10))
print("Accuracy on training data", accuracy(x, y, x, y, 10))
plt.scatter(x[:,0], x[:,1], c=y_pred)
plt.show()
# Out:
# Accuracy on training data 0.966666666667

# %% [markdown]
# ### Distance weighted KNN (classification)

# %%
def KNN(x, x_train, y_train, k):
    d = []
    for i in range(len(x_train)):
        d.append([distance(x, x_train[i]), y_train[i]])
    d = sorted(d, key = getkey)
    num_of_classes = len(np.unique(y_train))
    output = -1
    maximum = -1
    nearest_neighbours = [d[i][1] for i in range(k)]
    for i in range(num_of_classes):
        sum = 0
        for j in range(k):
            # uncommenting the next two lines would give 100% accuracy on the training set, use them only on test data
            #if d[j][1] == i and d[j][0] == 0:
            #    return i
            if d[j][0] != 0 and d[j][1] == i:
                sum += 1 / d[j][0]
        if sum > maximum:
            maximum = sum
            output = i
    return output

# %%
# Decision boundary generated
y_pred = []
for i in range(len(x)):
    y_pred.append(KNN(x[i], x, y, 10))
print("Accuracy on training data", accuracy(x, y, x, y, 5))
plt.scatter(x[:,0], x[:,1], c=y_pred)
plt.show()
# Out:
# Accuracy on training data 0.953333333333

# %% [markdown]
# ### For a regression problem

# %%
def KNN(x, x_train, y_train, k):
    d = [[distance(x, x_train[i]), y_train[i]] for i in range(len(x_train))]
    d = sorted(d, key = getkey)
    nearest_neighbours = [d[i][1] for i in range(k)]
    sum = 0
    for i in range(k):
        sum += nearest_neighbours[i]
    return sum / k

# %%
# r2_score on the training set
print(r2_score(x_train, y_train, x_train, y_train, 5))
# Out:
# 0.716098217737

# %% [markdown]
# ### Distance weighted KNN (regression)

# %%
def KNN(x, x_train, y_train, k):
    d = [[distance(x, x_train[i]), y_train[i]] for i in range(len(x_train))]
    d = sorted(d, key = getkey)
    nearest_neighbours = [d[i][1] for i in range(k)]
    num = 0
    den = np.sum([(1/d[i][0]) for i in range(k)])
    for i in range(k):
        num += (1/d[i][0]) * nearest_neighbours[i]
    return num / den

# %%
# r2_score on the training set
print(r2_score(x_train, y_train, x_train, y_train, 5))
# Out:
# C:\Users\Google\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#
# C:\Users\Google\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in double_scalars
#
# C:\Users\Google\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in double_scalars
#   if __name__ == '__main__':
# nan

# %% [markdown]
# ### Using KNN from sklearn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(n_neighbors=10)
clf.fit(x, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
# Decision boundary generated
y_pred = clf.predict(x)
print("Accuracy on the training set", (y_pred == y).sum() / len(y))
plt.scatter(x[:,0], x[:,1], c=y_pred)
plt.show()
# Out:
# Accuracy on the training set 0.966666666667
